# %% [markdown]
# # Data Manipulation Assignment: Combining and Analyzing Retail Data
#
# This assignment is designed to test your ability to work with multiple datasets using Pandas. You will be provided with separate files for customer information and sales transactions. Your task is to clean, combine, and analyze these datasets to gain a complete view of our business performance.
#
# ## The Datasets
#
# You will work with the following files:
#
# - `customers.csv`: Contains customer-level information (`CustomerID`, `CustomerName`, `CustomerAge`, `Gender`, `City`).
# - `online_sales.csv`: Contains online sales transactions (`TransactionID`, `CustomerID`, `ProductCategory`, `TransactionAmount`, `SalesChannel`, `PurchaseDate`).
# - `in_store_sales.csv`: Contains in-store sales transactions (`TransactionID`, `CustomerID`, `ProductCategory`, `TransactionAmount`, `SalesChannel`, `PurchaseDate`).

# %% [markdown]
# ## Part 1: Data Loading and Initial Inspection
#
# **Objective:** Load the three datasets and perform a preliminary inspection of their structure.
#
# 1.  Load `customers.csv`, `online_sales.csv`, and `in_store_sales.csv` into separate Pandas DataFrames.
# 2.  Display the first 5 rows and a summary (`.info()`) for each DataFrame to understand its structure.

# %%
#1.Load customers.csv, online_sales.csv, and in_store_sales.csv into separate Pandas DataFrames.
import pandas as pd
customers_df=pd.read_csv("customers.csv")
online_sales_df=pd.read_csv("online_sales.csv")
in_store_sales_df=pd.read_csv("in_store_sales.csv")
print("customers dataframe:")
print(customers_df)
print("*"*50)
print("online sales dataframe:")
print(online_sales_df)
print("*"*50)
print("in store sales dataframe:")
print(in_store_sales_df)
# Out:
# customers dataframe:
#       CustomerID     CustomerName  CustomerAge  Gender       City
# 0           1001       Isha Hegde           54    Male      Delhi
# 1           1002    Kavita DSouza           21    Male    Kolkata
# 2           1003       Diya Gupta           19  Female    Kolkata
# 3           1004   Vivaan Iyengar           45    Male  Hyderabad
# 4           1005   Ananya Iyengar           18  Female    Chennai
# ...          ...              ...          ...     ...        ...
# 4995        5996     Jatin Sastry           30  Female  Bangalore
# 4996        5997  Ankit Mukherjee           28  Female    Kolkata
# 4997        5998  Siddharth Patil           21  Female     Mumbai
# 4998        5999        Geeta Ali           46  Female      Delhi
# 4999        6000       Arjun Shah           33    Male    Chennai
#
# [5000 rows x 5 columns]
# **************************************************
# online sales dataframe:
#       TransactionID  CustomerID ProductCategory  TransactionAmount  \
# 0             10001        1603           Books        2708.445962
# 1             10002        4548         Apparel        2822.318124
# 2             10003        1784       Groceries        1935.709806
# 3             10004        5144     Electronics        1631.719666
# 4             10005        5458           Books        1482.805834
# ...             ...         ...             ...                ...
# 2495          12496        3404     Electronics        1623.160029
# 2496          12497        2822           Books         418.349493
# 2497          12498        5698     Electronics        3978.237164
# 2498          12499        4677         Apparel         582.395991
# 2499          12500        3428     Electronics        1123.550448
#
#      SalesChannel PurchaseDate
# 0          Online   2023-12-31
# 1          Online   2023-09-18
# 2          Online   2023-02-25
# 3          Online   2023-07-12
# 4          Online   2023-01-13
# ...           ...          ...
# 2495       Online   2023-04-06
# 2496       Online   2023-10-02
# 2497       Online   2023-02-01
# 2498       Online   2023-06-26
# 2499       Online   2023-03-07
#
# [2500 rows x 6 columns]
# **************************************************
# in store sales dataframe:
#       TransactionID  CustomerID ProductCategory  TransactionAmount  \
# 0             10001        3168     Electronics        4552.617515
# 1             10002        1053      Home Goods        1016.736564
# 2             10003        4149       Groceries        3139.867230
# 3             10004        1500      Home Goods        4107.785257
# 4             10005        3321     Electronics        4867.825187
# ...             ...         ...             ...                ...
# 2495          12496        2928     Electronics        3574.889331
# 2496          12497        2083      Home Goods        2602.340676
# 2497          12498        2805       Groceries         810.732073
# 2498          12499        3872     Electronics         496.210218
# 2499          12500        2491      Home Goods        1720.348466
#
#      SalesChannel PurchaseDate
# 0        In-Store   2023-06-17
# 1        In-Store   2023-07-19
# 2        In-Store   2023-08-22
# 3        In-Store   2023-11-04
# 4        In-Store   2023-04-09
# ...           ...          ...
# 2495     In-Store   2023-01-13
# 2496     In-Store   2023-09-07
# 2497     In-Store   2023-10-28
# 2498     In-Store   2023-09-04
# 2499     In-Store   2023-08-12
#
# [2500 rows x 6 columns]

# %%
#2.Display the first 5 rows and a summary (.info()) for each DataFrame to understand its structure.
print("Display the first 5 rows and a summary of customers dataframe:")
print(f"first 5 rows :") 
print(customers_df.head()) 
print("~"*60)
print(f"summary of customers dataframe :") 
print(customers_df.info())
print("~"*60)
print(f"first 5 rows :") 
print(online_sales_df.head())
print("~"*60)
print(f"summary of online sales dataframe :") 
print(online_sales_df.info())
print("~"*60)
print(f"first 5 rows :") 
print(in_store_sales_df.head())
print("~"*60)
print(f"summary of in store sales dataframe :") 
print(in_store_sales_df.info())
# Out:
# Display the first 5 rows and a summary of customers dataframe:
# first 5 rows :
#    CustomerID    CustomerName  CustomerAge  Gender       City
# 0        1001      Isha Hegde           54    Male      Delhi
# 1        1002   Kavita DSouza           21    Male    Kolkata
# 2        1003      Diya Gupta           19  Female    Kolkata
# 3        1004  Vivaan Iyengar           45    Male  Hyderabad
# 4        1005  Ananya Iyengar           18  Female    Chennai
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# summary of customers dataframe :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    5000 non-null   int64
#  1   CustomerName  5000 non-null   object
#  2   CustomerAge   5000 non-null   int64
#  3   Gender        5000 non-null   object
#  4   City          5000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 195.4+ KB
# None
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# first 5 rows :
#    TransactionID  CustomerID ProductCategory  TransactionAmount SalesChannel  \
# 0          10001        1603           Books        2708.445962       Online
# 1          10002        4548         Apparel        2822.318124       Online
# 2          10003        1784       Groceries        1935.709806       Online
# 3          10004        5144     Electronics        1631.719666       Online
# 4          10005        5458           Books        1482.805834       Online
#
#   PurchaseDate
# 0   2023-12-31
# 1   2023-09-18
# 2   2023-02-25
# 3   2023-07-12
# 4   2023-01-13
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# summary of online sales dataframe :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      2500 non-null   int64
#  1   CustomerID         2500 non-null   int64
#  2   ProductCategory    2500 non-null   object
#  3   TransactionAmount  2500 non-null   float64
#  4   SalesChannel       2500 non-null   object
#  5   PurchaseDate       2500 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 117.3+ KB
# None
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# first 5 rows :
#    TransactionID  CustomerID ProductCategory  TransactionAmount SalesChannel  \
# 0          10001        3168     Electronics        4552.617515     In-Store
# 1          10002        1053      Home Goods        1016.736564     In-Store
# 2          10003        4149       Groceries        3139.867230     In-Store
# 3          10004        1500      Home Goods        4107.785257     In-Store
# 4          10005        3321     Electronics        4867.825187     In-Store
#
#   PurchaseDate
# 0   2023-06-17
# 1   2023-07-19
# 2   2023-08-22
# 3   2023-11-04
# 4   2023-04-09
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# summary of in store sales dataframe :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      2500 non-null   int64
#  1   CustomerID         2500 non-null   int64
#  2   ProductCategory    2500 non-null   object
#  3   TransactionAmount  2500 non-null   float64
#  4   SalesChannel       2500 non-null   object
#  5   PurchaseDate       2500 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 117.3+ KB
# None

# %% [markdown]
# ## Part 2: Data Concatenation (`pd.concat`)
#
# **Objective:** Combine the sales data from different channels into a single, unified DataFrame.
#
# 3.  Concatenate the `online_sales` and `in_store_sales` DataFrames to create a new DataFrame called `all_sales_df`.
# 4.  Check the shape and the first 5 rows of `all_sales_df` to ensure the concatenation was successful.
# 5.  Check for and handle any duplicate entries in the `all_sales_df`.
# 6.  Display the counts of each `SalesChannel` to confirm all data was included.

# %%
#3.Concatenate the online_sales and in_store_sales DataFrames to create a new DataFrame called all_sales_df.
all_sales_df=pd.concat([online_sales_df,in_store_sales_df],ignore_index=True)
print("all sales dataframe:")
all_sales_df
# Out:
# all sales dataframe:
#       TransactionID  CustomerID ProductCategory  TransactionAmount  \
# 0             10001        1603           Books        2708.445962
# 1             10002        4548         Apparel        2822.318124
# 2             10003        1784       Groceries        1935.709806
# 3             10004        5144     Electronics        1631.719666
# 4             10005        5458           Books        1482.805834
# ...             ...         ...             ...                ...
# 4995          12496        2928     Electronics        3574.889331
# 4996          12497        2083      Home Goods        2602.340676
# 4997          12498        2805       Groceries         810.732073
# 4998          12499        3872     Electronics         496.210218
# 4999          12500        2491      Home Goods        1720.348466
#
#      SalesChannel PurchaseDate
# 0          Online   2023-12-31
# 1          Online   2023-09-18
# 2          Online   2023-02-25
# 3          Online   2023-07-12
# 4          Online   2023-01-13
# ...           ...          ...
# 4995     In-Store   2023-01-13
# 4996     In-Store   2023-09-07
# 4997     In-Store   2023-10-28
# 4998     In-Store   2023-09-04
# 4999     In-Store   2023-08-12
#
# [5000 rows x 6 columns]

# %%
#4.Check the shape and the first 5 rows of all_sales_df to ensure the concatenation was successful.
print("shape of all_sales_df:")
print(all_sales_df.shape)
print("~"*60)
print("the first 5 rows of all_sales_df:")
print(all_sales_df.head())
# Out:
# shape of all_sales_df:
# (5000, 6)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# the first 5 rows of all_sales_df:
#    TransactionID  CustomerID ProductCategory  TransactionAmount SalesChannel  \
# 0          10001        1603           Books        2708.445962       Online
# 1          10002        4548         Apparel        2822.318124       Online
# 2          10003        1784       Groceries        1935.709806       Online
# 3          10004        5144     Electronics        1631.719666       Online
# 4          10005        5458           Books        1482.805834       Online
#
#   PurchaseDate
# 0   2023-12-31
# 1   2023-09-18
# 2   2023-02-25
# 3   2023-07-12
# 4   2023-01-13

# %%
#5.Check for and handle any duplicate entries in the all_sales_df
print(all_sales_df.duplicated())
print("~"*60)
print(all_sales_df.duplicated().sum())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0

# %%
#6.Display the counts of each SalesChannel to confirm all data was included
all_sales_df["SalesChannel"].value_counts()
# Out:
# SalesChannel
# Online      2500
# In-Store    2500
# Name: count, dtype: int64

# %% [markdown]
# ## Part 3: Data Merging (`pd.merge`) and Analysis
#
# **Objective:** Join the combined sales data with the customer data to enable a rich, cross-dataset analysis.
#
# 7.  Merge the `all_sales_df` with the `customers` DataFrame on the common column `CustomerID`. Store the result in a new DataFrame called `combined_data`.
# 8.  Check the shape and `info()` of `combined_data` to ensure the join was successful.
# 9.  Find the top 5 cities with the highest total sales.
# 10. Calculate the average transaction amount for each `ProductCategory`.
# 11. Determine the number of unique customers who made a purchase in each `SalesChannel`.

# %%
#7.Merge the all_sales_df with the customers DataFrame on the common column CustomerID. Store the result in a new DataFrame called combined_data
combined_data=pd.merge(all_sales_df,customers_df,on="CustomerID",how="inner")
combined_data
# Out:
#       TransactionID  CustomerID ProductCategory  TransactionAmount  \
# 0             10001        1603           Books        2708.445962
# 1             10002        4548         Apparel        2822.318124
# 2             10003        1784       Groceries        1935.709806
# 3             10004        5144     Electronics        1631.719666
# 4             10005        5458           Books        1482.805834
# ...             ...         ...             ...                ...
# 4995          12496        2928     Electronics        3574.889331
# 4996          12497        2083      Home Goods        2602.340676
# 4997          12498        2805       Groceries         810.732073
# 4998          12499        3872     Electronics         496.210218
# 4999          12500        2491      Home Goods        1720.348466
#
#      SalesChannel PurchaseDate    CustomerName  CustomerAge  Gender       City
# 0          Online   2023-12-31     Jatin Ghosh           44    Male  Hyderabad
# 1          Online   2023-09-18   Sunita DSouza           31  Female       Pune
# 2          Online   2023-02-25    Geeta Prasad           18    Male  Hyderabad
# 3          Online   2023-07-12    Kavita Patel           29  Female    Chennai
# 4          Online   2023-01-13      Krish Jain           24    Male    Kolkata
# ...           ...          ...             ...          ...     ...        ...
# 4995     In-Store   2023-01-13    Geeta Sastry           39  Female  Bangalore
# 4996     In-Store   2023-09-07      Isha Dubey           43    Male       Pune
# 4997     In-Store   2023-10-28     Sunita Iyer           18  Female    Kolkata
# 4998     In-Store   2023-09-04  Ananya Iyengar           38  Female  Bangalore
# 4999     In-Store   2023-08-12     Ayaan Hegde           31    Male  Hyderabad
#
# [5000 rows x 10 columns]

# %%
#8.Check the shape and info() of combined_data to ensure the join was successful
print("shape of the combined data:")
print(combined_data.shape)
print("~"*60)
print("info of combined data:")
print(combined_data.info())
# Out:
# shape of the combined data:
# (5000, 10)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# info of combined data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TransactionID      5000 non-null   int64
#  1   CustomerID         5000 non-null   int64
#  2   ProductCategory    5000 non-null   object
#  3   TransactionAmount  5000 non-null   float64
#  4   SalesChannel       5000 non-null   object
#  5   PurchaseDate       5000 non-null   object
#  6   CustomerName       5000 non-null   object
#  7   CustomerAge        5000 non-null   int64
#  8   Gender             5000 non-null   object
#  9   City               5000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 390.8+ KB
# None

# %%
#9.Find the top 5 cities with the highest total sales.
sort=combined_data.groupby("City")["TransactionAmount"].sum().sort_values(ascending=False)
sort.head()
#sort_df=combined_data.sort_values("TransactionAmount",ascending=False)
#sort_df.sort_values("City",ascending=False).head()
# Out:
# City
# Hyderabad    1.925573e+06
# Bangalore    1.898252e+06
# Chennai      1.867940e+06
# Pune         1.798697e+06
# Delhi        1.720877e+06
# Name: TransactionAmount, dtype: float64

# %%
#10.Calculate the average transaction amount for each ProductCategory
avg_transaction=combined_data.groupby("ProductCategory")["TransactionAmount"].mean()
avg_transaction
# Out:
# ProductCategory
# Apparel        2504.997056
# Books          2494.497873
# Electronics    2517.665041
# Groceries      2464.130599
# Home Goods     2577.093138
# Name: TransactionAmount, dtype: float64

# %%
#11.Determine the number of unique customers who made a purchase in each SalesChannel
unique_cust=combined_data.groupby("SalesChannel")["CustomerName"].nunique()
unique_cust
# Out:
# SalesChannel
# In-Store    895
# Online      878
# Name: CustomerName, dtype: int64

# %% [markdown]
# ## Part 4: Data Visualization
#
# **Objective:** Create informative plots to visually represent key insights from the combined data.
#
# 12. Create a bar plot showing the total `TransactionAmount` for each `City`.
# 13. Visualize the total sales amount by `ProductCategory` using a bar plot.
# 14. Create a histogram of the `CustomerAge` distribution for customers who made a purchase.
# 15. Use a box plot to show the distribution of `TransactionAmount` across different `ProductCategory`s.
# 16. Create a bar plot to show the average `TransactionAmount` by `Gender`.

# %%
#12.Create a bar plot showing the total TransactionAmount for each City
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
total_transactionamount=combined_data.groupby("City")["TransactionAmount"].sum()
sns.barplot(total_transactionamount,color="skyblue")
plt.title("Total TransactionAmount For Each City",fontsize=10,fontweight="bold")
plt.xlabel("City")
plt.ylabel("TransactionAmount")
plt.show()

# %%
#13.Visualize the total sales amount by ProductCategory using a bar plot.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
total_transactionamount=combined_data.groupby("ProductCategory")["TransactionAmount"].sum()
sns.barplot(total_transactionamount,color="green")
plt.title("Total Sales Amount By ProductCategory Using a Bar Plot")
plt.xlabel("ProductCategory")
plt.ylabel("TransactionAmount")
plt.show()

# %%
#14.Create a histogram of the CustomerAge distribution for customers who made a purchase.
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.hist(combined_data["CustomerAge"],bins=12,edgecolor="green",color="pink")
plt.title("Histogram Of The CustomerAge Distribution For Customers Who Made a Purchase")
plt.xlabel("CustomerAge")
plt.ylabel("Customer purchase")
plt.show()

# %%
#15.Use a box plot to show the distribution of TransactionAmount across different ProductCategorys.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(x='ProductCategory', y='TransactionAmount',data=combined_data,color="red")
plt.title("Distribution Of TransactionAmount Across Different ProductCategorys")
plt.xlabel("ProductCategory")
plt.ylabel("TransactionAmount")
plt.show()

# %%
#16.Create a bar plot to show the average TransactionAmount by Gender.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
total_transactionamount=combined_data.groupby("Gender")["TransactionAmount"].mean()
sns.barplot(total_transactionamount,color="pink")
plt.title("Show The Average TransactionAmount By Gender")
plt.xlabel("Gender")
plt.ylabel("TransactionAmount")
plt.show()
